# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# #### Load dataset

# %%
df = pd.read_csv("survey_results.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30010 entries, 0 to 30009
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   respondent_id                   30010 non-null  object
#  1   age                             30010 non-null  int64
#  2   gender                          30010 non-null  object
#  3   zone                            30010 non-null  object
#  4   occupation                      30010 non-null  object
#  5   income_levels                   21946 non-null  object
#  6   consume_frequency(weekly)       30002 non-null  object
#  7   current_brand                   30010 non-null  object
#  8   preferable_consumption_size     30010 non-null  object
#  9   awareness_of_other_brands       30010 non-null  object
#  10  reasons_for_choosing_brands     30010 non-null  object
#  11  flavor_preference               30010 non-null  object
#  12  purchase_channel                30000 non-null  object
#  13  packaging_preference            30010 non-null  object
#  14  health_concerns                 30010 non-null  object
#  15  typical_consumption_situations  30010 non-null  object
#  16  price_range                     30010 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 3.9+ MB

# %%
df[df.duplicated(keep=False)].shape
# Out:
# (20, 17)

# %%
# There are 10 duplicates

# %%
df = df.drop_duplicates(keep='first')

# %%
df['age'].max()
# Out:
# 604

# %%
df['age'].min()
# Out:
# 18

# %%
df.loc[df['age'] > 100,:].shape
# Out:
# (9, 17)

# %%
# Drop 9 records that have extremely high age values

# %%
df = df[df['age'] < 100]
df.shape
# Out:
# (29991, 17)

# %%
df['income_levels'].value_counts()
# Out:
# income_levels
# 16L - 25L    5897
# 10L - 15L    5251
# <10L         4661
# 26L - 35L    3872
# > 35L        2250
# Name: count, dtype: int64

# %%
df['income_levels'].isnull().sum()
# Out:
# 8060

# %%
df.loc[df['income_levels'].isnull(), 'income_levels'] = "Not_reported"

# %%
df['income_levels'].value_counts()
# Out:
# income_levels
# Not_reported    8060
# 16L - 25L       5897
# 10L - 15L       5251
# <10L            4661
# 26L - 35L       3872
# > 35L           2250
# Name: count, dtype: int64

# %%
# Missing income levels indicated as "Not_reported"

# %%
df["consume_frequency(weekly)"].value_counts()
# Out:
# consume_frequency(weekly)
# 3-4 times    11786
# 5-7 times     9774
# 0-2 times     8423
# Name: count, dtype: int64

# %%
df.loc[df['consume_frequency(weekly)'].isnull(),:].shape
# Out:
# (8, 17)

# %%
df["consume_frequency(weekly)"].mode()[0]
# Out:
# '3-4 times'

# %%
# Simply replace null-values in "consume_frequency(weekly)" with mode.
# It's not going to have big impact as there are only 8 such records out of 30010.

# %%
df.loc[df['consume_frequency(weekly)'].isnull(),"consume_frequency(weekly)"] = df["consume_frequency(weekly)"].mode()[0]

# %%
df["consume_frequency(weekly)"].value_counts()
# Out:
# consume_frequency(weekly)
# 3-4 times    11794
# 5-7 times     9774
# 0-2 times     8423
# Name: count, dtype: int64

# %%
df["purchase_channel"].value_counts()
# Out:
# purchase_channel
# Online          16562
# Retail Store    13419
# Name: count, dtype: int64

# %%
df["purchase_channel"].mode()[0]
# Out:
# 'Online'

# %%
df.loc[df['purchase_channel'].isnull(),:].shape
# Out:
# (10, 17)

# %%
# Simply replace null-values in "purchase_channel" with mode. 
# It's not going to have big impact as there are only 10 such records out of 30010.

# %%
df.loc[df['purchase_channel'].isnull(),"purchase_channel"] = df["purchase_channel"].mode()[0]

# %%
df['zone'].value_counts()
# Out:
# zone
# Metro         11906
# Urban         10686
# Semi-Urban     5274
# Rural          2116
# urbna             5
# Metor             4
# Name: count, dtype: int64

# %%
df.loc[df['zone'] == "Metor", 'zone'] = "Metro"
df.loc[df['zone'] == "urbna", 'zone'] = "Urban"

df['zone'].value_counts()
# Out:
# zone
# Metro         11910
# Urban         10691
# Semi-Urban     5274
# Rural          2116
# Name: count, dtype: int64

# %%
df['current_brand'].value_counts()
# Out:
# current_brand
# Established    15442
# Newcomer       14499
# newcomer          30
# Establishd        20
# Name: count, dtype: int64

# %%
df.loc[df['current_brand'] == "Establishd", 'current_brand'] = "Established"
df.loc[df['current_brand'] == "newcomer", 'current_brand'] = "Newcomer"

df['current_brand'].value_counts()
# Out:
# current_brand
# Established    15462
# Newcomer       14529
# Name: count, dtype: int64

# %% [markdown]
# #### Feature engineering

# %%
bins = [18, 25, 35, 45, 55, float('inf')]
labels = ['18–25', '26–35', '36–45', '46–55', '56+']

df['age_group'] = pd.cut(
    df['age'], 
    bins=bins, 
    labels=labels, 
    right=True,
    include_lowest=True
)

# %%
df['age_group'].value_counts()
# Out:
# age_group
# 18–25    10468
# 26–35     9093
# 36–45     5972
# 46–55     2966
# 56+       1492
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (29991, 18)

# %%
df = df.drop(columns=['age'])
df.shape
# Out:
# (29991, 17)

# %%
df['consume_frequency(weekly)'].value_counts()
# Out:
# consume_frequency(weekly)
# 3-4 times    11794
# 5-7 times     9774
# 0-2 times     8423
# Name: count, dtype: int64

# %%
cf_mapping = {
    "0-2 times" : 1,
    "3-4 times" : 2,
    "5-7 times" : 3
}

df['cf_score'] = df['consume_frequency(weekly)'].map(cf_mapping)

df['cf_score'].value_counts()
# Out:
# cf_score
# 2    11794
# 3     9774
# 1     8423
# Name: count, dtype: int64

# %%
df['awareness_of_other_brands'].value_counts()
# Out:
# awareness_of_other_brands
# 0 to 1     12966
# 2 to 4     11225
# above 4     5800
# Name: count, dtype: int64

# %%
ab_mapping = {
    "0 to 1" : 1,
    "2 to 4" : 2,
    "above 4" : 3
}

df['ab_score'] = df['awareness_of_other_brands'].map(ab_mapping)

df['ab_score'].value_counts()
# Out:
# ab_score
# 1    12966
# 2    11225
# 3     5800
# Name: count, dtype: int64

# %%
df['cf_ab_score'] = df['cf_score'] / (df['cf_score'] + df['ab_score'])
df[['cf_score', 'ab_score', 'cf_ab_score']].sample(5)
# Out:
#        cf_score  ab_score  cf_ab_score
# 24253         1         1         0.50
# 5788          3         1         0.75
# 28846         3         1         0.75
# 12859         3         1         0.75
# 21598         2         3         0.40

# %%
df['zone'].value_counts()
# Out:
# zone
# Metro         11910
# Urban         10691
# Semi-Urban     5274
# Rural          2116
# Name: count, dtype: int64

# %%
zone_mapping = {
    "Rural" : 1,
    "Semi-Urban" : 2,
    "Urban" : 3,
    "Metro" : 4
}

df['zone_score'] = df['zone'].map(zone_mapping)

df['zone_score'].value_counts()
# Out:
# zone_score
# 4    11910
# 3    10691
# 2     5274
# 1     2116
# Name: count, dtype: int64

# %%
df['income_levels'].value_counts()
# Out:
# income_levels
# Not_reported    8060
# 16L - 25L       5897
# 10L - 15L       5251
# <10L            4661
# 26L - 35L       3872
# > 35L           2250
# Name: count, dtype: int64

# %%
income_mapping = {
    "Not_reported" : 0,
    "<10L" : 1,
    "10L - 15L" : 2,
    "16L - 25L" : 3,
    "26L - 35L" : 4,
    "> 35L" : 5
}

df['income_score'] = df['income_levels'].map(income_mapping)

df['income_score'].value_counts()
# Out:
# income_score
# 0    8060
# 3    5897
# 2    5251
# 1    4661
# 4    3872
# 5    2250
# Name: count, dtype: int64

# %%
df['zas_score'] = df['zone_score'] * df['income_score']
df[['zone_score', 'income_score', 'zas_score']].sample(5)
# Out:
#        zone_score  income_score  zas_score
# 22545           3             2          6
# 16608           3             0          0
# 12321           4             4         16
# 18401           2             0          0
# 21363           4             0          0

# %%
df['reasons_for_choosing_brands'].value_counts()
# Out:
# reasons_for_choosing_brands
# Price               14138
# Availability         6590
# Brand Reputation     4661
# Quality              4602
# Name: count, dtype: int64

# %%
df['current_brand'].value_counts()
# Out:
# current_brand
# Established    15462
# Newcomer       14529
# Name: count, dtype: int64

# %%
df['bsi'] = np.where(
    (df['current_brand'] != "Established") & (df['reasons_for_choosing_brands'].isin(['Price','Quality'])),
    1,
    0
)

df[['current_brand','reasons_for_choosing_brands','bsi']].sample(5)
# Out:
#       current_brand reasons_for_choosing_brands  bsi
# 14546   Established            Brand Reputation    0
# 20693   Established            Brand Reputation    0
# 7089       Newcomer                       Price    1
# 23120      Newcomer                       Price    1
# 17654   Established                     Quality    0

# %%
pd.crosstab(df['age_group'],df['occupation'])
# Out:
# occupation  Entrepreneur  Retired  Student  Working Professional
# age_group
# 18–25                535        0     7328                  2605
# 26–35               1826        0      697                  6570
# 36–45               1619        0        0                  4353
# 46–55                799        0        0                  2167
# 56+                  221     1130       35                   106

# %%
df.loc[(df['age_group'] == "56+") & (df['occupation'] == 'Student'), :]
# Out:
#       respondent_id gender        zone occupation income_levels  \
# 182          R00183      F       Urban    Student  Not_reported
# 3526         R03525      F  Semi-Urban    Student  Not_reported
# 3527         R03526      M  Semi-Urban    Student  Not_reported
# 3772         R03771      M       Metro    Student  Not_reported
# 4033         R04032      M       Urban    Student  Not_reported
# 6545         R06543      F       Urban    Student  Not_reported
# 6594         R06592      M  Semi-Urban    Student  Not_reported
# 6648         R06646      F  Semi-Urban    Student  Not_reported
# 7420         R07418      F       Rural    Student  Not_reported
# 7596         R07594      M       Urban    Student  Not_reported
# 7841         R07838      F       Metro    Student  Not_reported
# 9090         R09086      F       Urban    Student  Not_reported
# 9198         R09194      M       Urban    Student  Not_reported
# 11877        R11872      M       Metro    Student  Not_reported
# 12031        R12026      M       Urban    Student  Not_reported
# 12471        R12466      F       Metro    Student  Not_reported
# 15711        R15706      F       Metro    Student  Not_reported
# 16230        R16225      M       Urban    Student  Not_reported
# 16829        R16824      M  Semi-Urban    Student  Not_reported
# 17202        R17197      M       Metro    Student  Not_reported
# 19103        R19097      M  Semi-Urban    Student  Not_reported
# 20218        R20212      F       Metro    Student  Not_reported
# 21422        R21416      F       Urban    Student  Not_reported
# 24252        R24244      F       Urban    Student  Not_reported
# 24885        R24877      M       Urban    Student  Not_reported
# 25090        R25081      F  Semi-Urban    Student  Not_reported
# 25133        R25124      F       Urban    Student  Not_reported
# 25443        R25434      M       Rural    Student  Not_reported
# 25544        R25535      F       Rural    Student  Not_reported
# 25723        R25714      F       Urban    Student  Not_reported
# 25819        R25810      M       Urban    Student  Not_reported
# 26066        R26057      M  Semi-Urban    Student  Not_reported
# 26851        R26842      F       Metro    Student  Not_reported
# 28578        R28569      F       Metro    Student  Not_reported
# 28910        R28901      M  Semi-Urban    Student  Not_reported
#
#       consume_frequency(weekly) current_brand preferable_consumption_size  \
# 182                   5-7 times   Established                 Large (1 L)
# 3526                  0-2 times   Established             Medium (500 ml)
# 3527                  0-2 times      Newcomer              Small (250 ml)
# 3772                  5-7 times      Newcomer             Medium (500 ml)
# 4033                  3-4 times   Established             Medium (500 ml)
# 6545                  5-7 times      Newcomer             Medium (500 ml)
# 6594                  5-7 times   Established             Medium (500 ml)
# 6648                  0-2 times   Established             Medium (500 ml)
# 7420                  3-4 times   Established              Small (250 ml)
# 7596                  5-7 times      Newcomer             Medium (500 ml)
# 7841                  0-2 times   Established                 Large (1 L)
# 9090                  3-4 times      Newcomer              Small (250 ml)
# 9198                  3-4 times   Established                 Large (1 L)
# 11877                 0-2 times   Established              Small (250 ml)
# 12031                 3-4 times      Newcomer                 Large (1 L)
# 12471                 5-7 times      Newcomer             Medium (500 ml)
# 15711                 5-7 times      Newcomer             Medium (500 ml)
# 16230                 5-7 times   Established             Medium (500 ml)
# 16829                 0-2 times   Established              Small (250 ml)
# 17202                 0-2 times   Established             Medium (500 ml)
# 19103                 0-2 times      Newcomer              Small (250 ml)
# 20218                 3-4 times   Established             Medium (500 ml)
# 21422                 0-2 times      Newcomer              Small (250 ml)
# 24252                 5-7 times      Newcomer              Small (250 ml)
# 24885                 0-2 times   Established             Medium (500 ml)
# 25090                 0-2 times      Newcomer             Medium (500 ml)
# 25133                 0-2 times   Established              Small (250 ml)
# 25443                 0-2 times      Newcomer             Medium (500 ml)
# 25544                 0-2 times   Established              Small (250 ml)
# 25723                 0-2 times      Newcomer              Small (250 ml)
# 25819                 3-4 times      Newcomer                 Large (1 L)
# 26066                 0-2 times      Newcomer              Small (250 ml)
# 26851                 0-2 times      Newcomer             Medium (500 ml)
# 28578                 0-2 times   Established             Medium (500 ml)
# 28910                 3-4 times   Established              Small (250 ml)
#
#       awareness_of_other_brands reasons_for_choosing_brands  ...  \
# 182                     above 4                       Price  ...
# 3526                     0 to 1                       Price  ...
# 3527                     2 to 4                       Price  ...
# 3772                     2 to 4                Availability  ...
# 4033                     0 to 1                       Price  ...
# 6545                     0 to 1                       Price  ...
# 6594                     0 to 1                Availability  ...
# 6648                     2 to 4                       Price  ...
# 7420                     0 to 1                       Price  ...
# 7596                     2 to 4                       Price  ...
# 7841                     0 to 1                       Price  ...
# 9090                     0 to 1                       Price  ...
# 9198                     0 to 1                       Price  ...
# 11877                    0 to 1                       Price  ...
# 12031                    2 to 4                       Price  ...
# 12471                   above 4                       Price  ...
# 15711                    2 to 4                       Price  ...
# 16230                    2 to 4                       Price  ...
# 16829                   above 4                Availability  ...
# 17202                    0 to 1                Availability  ...
# 19103                    0 to 1                       Price  ...
# 20218                    0 to 1                Availability  ...
# 21422                    2 to 4                       Price  ...
# 24252                    0 to 1                       Price  ...
# 24885                    0 to 1                       Price  ...
# 25090                    0 to 1                       Price  ...
# 25133                    0 to 1                       Price  ...
# 25443                    0 to 1                       Price  ...
# 25544                    0 to 1                Availability  ...
# 25723                   above 4                       Price  ...
# 25819                    2 to 4                       Price  ...
# 26066                    0 to 1                       Price  ...
# 26851                    0 to 1                Availability  ...
# 28578                    2 to 4                       Price  ...
# 28910                    0 to 1                       Price  ...
#
#       typical_consumption_situations price_range age_group cf_score ab_score  \
# 182             Casual (eg. At home)     150-200       56+        3        3
# 3526        Active (eg. Sports, gym)      50-100       56+        1        1
# 3527            Casual (eg. At home)     100-150       56+        1        2
# 3772        Active (eg. Sports, gym)     150-200       56+        3        2
# 4033            Social (eg. Parties)     150-200       56+        2        1
# 6545            Social (eg. Parties)     150-200       56+        3        1
# 6594            Casual (eg. At home)     100-150       56+        3        1
# 6648            Casual (eg. At home)     100-150       56+        1        2
# 7420        Active (eg. Sports, gym)     100-150       56+        2        1
# 7596        Active (eg. Sports, gym)     200-250       56+        3        2
# 7841            Casual (eg. At home)     100-150       56+        1        1
# 9090            Casual (eg. At home)     150-200       56+        2        1
# 9198        Active (eg. Sports, gym)     100-150       56+        2        1
# 11877           Casual (eg. At home)     100-150       56+        1        1
# 12031           Casual (eg. At home)     150-200       56+        2        2
# 12471       Active (eg. Sports, gym)     200-250       56+        3        3
# 15711       Active (eg. Sports, gym)     200-250       56+        3        2
# 16230       Active (eg. Sports, gym)     150-200       56+        3        2
# 16829       Active (eg. Sports, gym)     100-150       56+        1        3
# 17202           Social (eg. Parties)     100-150       56+        1        1
# 19103           Casual (eg. At home)     100-150       56+        1        1
# 20218           Casual (eg. At home)     150-200       56+        2        1
# 21422           Casual (eg. At home)     150-200       56+        1        2
# 24252       Active (eg. Sports, gym)     100-150       56+        3        1
# 24885       Active (eg. Sports, gym)      50-100       56+        1        1
# 25090           Social (eg. Parties)     100-150       56+        1        1
# 25133           Casual (eg. At home)     150-200       56+        1        1
# 25443           Social (eg. Parties)     100-150       56+        1        1
# 25544           Social (eg. Parties)     100-150       56+        1        1
# 25723           Casual (eg. At home)     150-200       56+        1        3
# 25819       Active (eg. Sports, gym)     150-200       56+        2        2
# 26066           Casual (eg. At home)     100-150       56+        1        1
# 26851           Social (eg. Parties)     100-150       56+        1        1
# 28578           Casual (eg. At home)     100-150       56+        1        2
# 28910       Active (eg. Sports, gym)     100-150       56+        2        1
#
#       cf_ab_score zone_score  income_score  zas_score  bsi
# 182      0.500000          3             0          0    0
# 3526     0.500000          2             0          0    0
# 3527     0.333333          2             0          0    1
# 3772     0.600000          4             0          0    0
# 4033     0.666667          3             0          0    0
# 6545     0.750000          3             0          0    1
# 6594     0.750000          2             0          0    0
# 6648     0.333333          2             0          0    0
# 7420     0.666667          1             0          0    0
# 7596     0.600000          3             0          0    1
# 7841     0.500000          4             0          0    0
# 9090     0.666667          3             0          0    1
# 9198     0.666667          3             0          0    0
# 11877    0.500000          4             0          0    0
# 12031    0.500000          3             0          0    1
# 12471    0.500000          4             0          0    1
# 15711    0.600000          4             0          0    1
# 16230    0.600000          3             0          0    0
# 16829    0.250000          2             0          0    0
# 17202    0.500000          4             0          0    0
# 19103    0.500000          2             0          0    1
# 20218    0.666667          4             0          0    0
# 21422    0.333333          3             0          0    1
# 24252    0.750000          3             0          0    1
# 24885    0.500000          3             0          0    0
# 25090    0.500000          2             0          0    1
# 25133    0.500000          3             0          0    0
# 25443    0.500000          1             0          0    1
# 25544    0.500000          1             0          0    0
# 25723    0.250000          3             0          0    1
# 25819    0.500000          3             0          0    1
# 26066    0.500000          2             0          0    1
# 26851    0.500000          4             0          0    0
# 28578    0.333333          4             0          0    0
# 28910    0.666667          2             0          0    0
#
# [35 rows x 24 columns]

# %%
df.shape
# Out:
# (29991, 24)

# %%
df = df.loc[~((df['age_group'] == "56+") & (df['occupation'] == 'Student')), :]

# %%
df.shape
# Out:
# (29956, 24)

# %%
df['zas_score'].nunique()
# Out:
# 14

# %%
df.loc[df['bsi'] == 0, :].shape
# Out:
# (20796, 24)

# %% [markdown]
# ### MODEL BUILDING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29956 entries, 0 to 30009
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   respondent_id                   29956 non-null  object
#  1   gender                          29956 non-null  object
#  2   zone                            29956 non-null  object
#  3   occupation                      29956 non-null  object
#  4   income_levels                   29956 non-null  object
#  5   consume_frequency(weekly)       29956 non-null  object
#  6   current_brand                   29956 non-null  object
#  7   preferable_consumption_size     29956 non-null  object
#  8   awareness_of_other_brands       29956 non-null  object
#  9   reasons_for_choosing_brands     29956 non-null  object
#  10  flavor_preference               29956 non-null  object
#  11  purchase_channel                29956 non-null  object
#  12  packaging_preference            29956 non-null  object
#  13  health_concerns                 29956 non-null  object
#  14  typical_consumption_situations  29956 non-null  object
#  15  price_range                     29956 non-null  object
#  16  age_group                       29956 non-null  category
#  17  cf_score                        29956 non-null  int64
#  18  ab_score                        29956 non-null  int64
#  19  cf_ab_score                     29956 non-null  float64
#  20  zone_score                      29956 non-null  int64
#  21  income_score                    29956 non-null  int64
#  22  zas_score                       29956 non-null  int64
#  23  bsi                             29956 non-null  int32
# dtypes: category(1), float64(1), int32(1), int64(5), object(16)
# memory usage: 5.4+ MB

# %% [markdown]
# #### Exclude these columns from model building process.

# %%
columns_to_exclude = ['respondent_id','income_levels','awareness_of_other_brands','consume_frequency(weekly)','zone','price_range']

X = df.drop(columns=columns_to_exclude)
y = df['price_range']

# %%
from sklearn.model_selection import train_test_split

# train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,      # 25% test
    random_state=42,    
    stratify=y          
)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22467 entries, 11016 to 11163
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   gender                          22467 non-null  object
#  1   occupation                      22467 non-null  object
#  2   current_brand                   22467 non-null  object
#  3   preferable_consumption_size     22467 non-null  object
#  4   reasons_for_choosing_brands     22467 non-null  object
#  5   flavor_preference               22467 non-null  object
#  6   purchase_channel                22467 non-null  object
#  7   packaging_preference            22467 non-null  object
#  8   health_concerns                 22467 non-null  object
#  9   typical_consumption_situations  22467 non-null  object
#  10  age_group                       22467 non-null  category
#  11  cf_score                        22467 non-null  int64
#  12  ab_score                        22467 non-null  int64
#  13  cf_ab_score                     22467 non-null  float64
#  14  zone_score                      22467 non-null  int64
#  15  income_score                    22467 non-null  int64
#  16  zas_score                       22467 non-null  int64
#  17  bsi                             22467 non-null  int32
# dtypes: category(1), float64(1), int32(1), int64(5), object(10)
# memory usage: 3.0+ MB

# %% [markdown]
# #### Perform label-encoding & one-hot encoding on respective columns

# %%
label_encode_columns = ['preferable_consumption_size','health_concerns','age_group']

one_hot_encode_columns = ['typical_consumption_situations','gender','occupation','current_brand','reasons_for_choosing_brands',
                          'flavor_preference','purchase_channel']

# %%
df['zone_score'].value_counts()
# Out:
# zone_score
# 4    11901
# 3    10677
# 2     5265
# 1     2113
# Name: count, dtype: int64

# %%
df['income_score'].value_counts()
# Out:
# income_score
# 0    8025
# 3    5897
# 2    5251
# 1    4661
# 4    3872
# 5    2250
# Name: count, dtype: int64

# %%
df['age_group'].value_counts()
# Out:
# age_group
# 18–25    10468
# 26–35     9093
# 36–45     5972
# 46–55     2966
# 56+       1457
# Name: count, dtype: int64

# %%
df['typical_consumption_situations'].value_counts()
# Out:
# typical_consumption_situations
# Active (eg. Sports, gym)    11238
# Casual (eg. At home)        10062
# Social (eg. Parties)         8656
# Name: count, dtype: int64

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Working Professional    15801
# Student                  8025
# Entrepreneur             5000
# Retired                  1130
# Name: count, dtype: int64

# %%
df['current_brand'].value_counts()
# Out:
# current_brand
# Established    15444
# Newcomer       14512
# Name: count, dtype: int64

# %%
df['preferable_consumption_size'].value_counts()
# Out:
# preferable_consumption_size
# Medium (500 ml)    13205
# Small (250 ml)      9709
# Large (1 L)         7042
# Name: count, dtype: int64

# %%
df['reasons_for_choosing_brands'].value_counts()
# Out:
# reasons_for_choosing_brands
# Price               14110
# Availability         6583
# Brand Reputation     4661
# Quality              4602
# Name: count, dtype: int64

# %%
df['flavor_preference'].value_counts()
# Out:
# flavor_preference
# Traditional    15085
# Exotic         14871
# Name: count, dtype: int64

# %%
df['purchase_channel'].value_counts()
# Out:
# purchase_channel
# Online          16561
# Retail Store    13395
# Name: count, dtype: int64

# %%
df['packaging_preference'].value_counts()
# Out:
# packaging_preference
# Simple          14422
# Premium         11692
# Eco-Friendly     3842
# Name: count, dtype: int64

# %%
df['health_concerns'].value_counts()
# Out:
# health_concerns
# High (Very health-conscious)            11893
# Medium (Moderately health-conscious)    10624
# Low (Not very concerned)                 7439
# Name: count, dtype: int64

# %%
manual_mappings = {
    'age_group': {
        '18–25': 0,
        '26–35': 1,
        '36–45': 2,
        '46–55': 3,
        '56+': 4
    },
    'preferable_consumption_size': {
        'Small (250 ml)': 0,
        'Medium (500 ml)': 1,
        'Large (1 L)': 2
    },
    'health_concerns': {
        "Low (Not very concerned)": 0,
        "Medium (Moderately health-conscious)": 1,
        "High (Very health-conscious)": 2
    }
}

# %%
for col in label_encode_columns:
    X_train[col] = X_train[col].map(manual_mappings[col])

# %%
for col in label_encode_columns:
    X_test[col] = X_test[col].map(manual_mappings[col])

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22467 entries, 11016 to 11163
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   gender                          22467 non-null  object
#  1   occupation                      22467 non-null  object
#  2   current_brand                   22467 non-null  object
#  3   preferable_consumption_size     22467 non-null  int64
#  4   reasons_for_choosing_brands     22467 non-null  object
#  5   flavor_preference               22467 non-null  object
#  6   purchase_channel                22467 non-null  object
#  7   packaging_preference            22467 non-null  object
#  8   health_concerns                 22467 non-null  int64
#  9   typical_consumption_situations  22467 non-null  object
#  10  age_group                       22467 non-null  category
#  11  cf_score                        22467 non-null  int64
#  12  ab_score                        22467 non-null  int64
#  13  cf_ab_score                     22467 non-null  float64
#  14  zone_score                      22467 non-null  int64
#  15  income_score                    22467 non-null  int64
#  16  zas_score                       22467 non-null  int64
#  17  bsi                             22467 non-null  int32
# dtypes: category(1), float64(1), int32(1), int64(7), object(8)
# memory usage: 3.0+ MB

# %%
X_train['preferable_consumption_size'].head()
# Out:
# 11016    0
# 25446    1
# 8271     0
# 18828    1
# 9399     0
# Name: preferable_consumption_size, dtype: int64

# %%
X_train['age_group'] = X_train['age_group'].astype('int64')
X_test['age_group'] = X_test['age_group'].astype('int64')

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7489 entries, 28481 to 6945
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   gender                          7489 non-null   object
#  1   occupation                      7489 non-null   object
#  2   current_brand                   7489 non-null   object
#  3   preferable_consumption_size     7489 non-null   int64
#  4   reasons_for_choosing_brands     7489 non-null   object
#  5   flavor_preference               7489 non-null   object
#  6   purchase_channel                7489 non-null   object
#  7   packaging_preference            7489 non-null   object
#  8   health_concerns                 7489 non-null   int64
#  9   typical_consumption_situations  7489 non-null   object
#  10  age_group                       7489 non-null   int64
#  11  cf_score                        7489 non-null   int64
#  12  ab_score                        7489 non-null   int64
#  13  cf_ab_score                     7489 non-null   float64
#  14  zone_score                      7489 non-null   int64
#  15  income_score                    7489 non-null   int64
#  16  zas_score                       7489 non-null   int64
#  17  bsi                             7489 non-null   int32
# dtypes: float64(1), int32(1), int64(8), object(8)
# memory usage: 1.1+ MB

# %%
X_train = pd.get_dummies(
    X_train,
    columns=X_train.select_dtypes(include='object').columns,
    drop_first=True
)

X_test = pd.get_dummies(
    X_test,
    columns=X_test.select_dtypes(include='object').columns,
    drop_first=True
)

# %%
X_train.head()
# Out:
#        preferable_consumption_size  health_concerns  age_group  cf_score  \
# 11016                            0                2          1         3
# 25446                            1                1          3         1
# 8271                             0                1          1         1
# 18828                            1                0          3         2
# 9399                             0                2          2         2
#
#        ab_score  cf_ab_score  zone_score  income_score  zas_score  bsi  ...  \
# 11016         3     0.500000           3             1          3    1  ...
# 25446         3     0.250000           4             3         12    0  ...
# 8271          2     0.333333           2             3          6    0  ...
# 18828         1     0.666667           1             1          1    0  ...
# 9399          1     0.666667           4             4         16    0  ...
#
#        current_brand_Newcomer  reasons_for_choosing_brands_Brand Reputation  \
# 11016                    True                                         False
# 25446                    True                                         False
# 8271                    False                                          True
# 18828                   False                                         False
# 9399                    False                                         False
#
#        reasons_for_choosing_brands_Price  reasons_for_choosing_brands_Quality  \
# 11016                               True                                False
# 25446                              False                                False
# 8271                               False                                False
# 18828                               True                                False
# 9399                               False                                 True
#
#        flavor_preference_Traditional  purchase_channel_Retail Store  \
# 11016                           True                          False
# 25446                          False                           True
# 8271                            True                           True
# 18828                           True                          False
# 9399                           False                          False
#
#        packaging_preference_Premium  packaging_preference_Simple  \
# 11016                         False                         True
# 25446                         False                        False
# 8271                           True                        False
# 18828                          True                        False
# 9399                          False                         True
#
#        typical_consumption_situations_Casual (eg. At home)  \
# 11016                                              False
# 25446                                              False
# 8271                                                True
# 18828                                               True
# 9399                                               False
#
#        typical_consumption_situations_Social (eg. Parties)
# 11016                                               True
# 25446                                               True
# 8271                                               False
# 18828                                              False
# 9399                                                True
#
# [5 rows x 24 columns]

# %%
y_train.value_counts()
# Out:
# price_range
# 200-250    7283
# 150-200    6598
# 100-150    5845
# 50-100     2741
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# price_range
# 200-250    2428
# 150-200    2199
# 100-150    1948
# 50-100      914
# Name: count, dtype: int64

# %%
manual_mappings_target = {
    '50-100': 0,
    '100-150': 1,
    '150-200': 2,
    '200-250': 3,
}

# %%
y_train = y_train.map(manual_mappings_target).astype('int64')
y_test = y_test.map(manual_mappings_target).astype('int64')

# %%
y_train.value_counts()
# Out:
# price_range
# 3    7283
# 2    6598
# 1    5845
# 0    2741
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# price_range
# 3    2428
# 2    2199
# 1    1948
# 0     914
# Name: count, dtype: int64

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# #### Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report

model_nb = GaussianNB()
model_nb.fit(X_train,y_train)

y_pred = model_nb.predict(X_test)

accuracy_nb = accuracy_score(y_test, y_pred)
print("Accuracy on Test Data using NB:", accuracy_nb)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on Test Data using NB: 0.5670984110028041
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.42      0.93      0.58       914
#            1       0.48      0.26      0.33      1948
#            2       0.57      0.33      0.42      2199
#            3       0.69      0.90      0.78      2428
#
#     accuracy                           0.57      7489
#    macro avg       0.54      0.60      0.53      7489
# weighted avg       0.57      0.57      0.53      7489

# %%
report_dict_gnb = classification_report(y_test, y_pred, output_dict=True)
report_dict_gnb
# Out:
# {'0': {'precision': 0.4175715695952616,
#   'recall': 0.925601750547046,
#   'f1-score': 0.5755102040816327,
#   'support': 914.0},
#  '1': {'precision': 0.47564469914040114,
#   'recall': 0.25564681724845995,
#   'f1-score': 0.3325542570951586,
#   'support': 1948.0},
#  '2': {'precision': 0.5707509881422925,
#   'recall': 0.32833105957253295,
#   'f1-score': 0.4168591224018476,
#   'support': 2199.0},
#  '3': {'precision': 0.6921612186607426,
#   'recall': 0.8982701812191104,
#   'f1-score': 0.7818605484853917,
#   'support': 2428.0},
#  'accuracy': 0.5670984110028041,
#  'macro avg': {'precision': 0.5390321188846745,
#   'recall': 0.6019624521467873,
#   'f1-score': 0.5266960330160076,
#   'support': 7489.0},
#  'weighted avg': {'precision': 0.5666798171142683,
#   'recall': 0.5670984110028041,
#   'f1-score': 0.5326295421599913,
#   'support': 7489.0}}

# %%
nb_params = model_nb.get_params()
nb_params
# Out:
# {'priors': None, 'var_smoothing': 1e-09}

# %%
import mlflow
# Out:
# C:\Users\Inspire\AppData\Local\Programs\Python\Python310\lib\site-packages\mlflow\protos\service_pb2.py:11: UserWarning: google.protobuf.service module is deprecated. RPC implementations should provide code generator plugins which generate code specific to the RPC implementation. service.py will be removed in Jan 2025
#   from google.protobuf import service as _service

# %% [markdown]
# #### Use below code to log models one-by-one

# %%
# mlflow.set_experiment("Beverage Price Predictor")
# mlflow.set_tracking_uri("http://127.0.0.1:5000")

# with mlflow.start_run(run_name='Gaussian NB'):
#     mlflow.log_params(nb_params)
#     mlflow.log_metrics(
#         {'accuracy' : report_dict_gnb['accuracy'],
#          'recall_class_0' : report_dict_gnb['0']['recall'],
#          'recall_class_1' : report_dict_gnb['1']['recall'],
#          'recall_class_2' : report_dict_gnb['2']['recall'],
#          'recall_class_3' : report_dict_gnb['3']['recall'],
#          'precision_class_0' : report_dict_gnb['0']['precision'],
#          'precision_class_1' : report_dict_gnb['1']['precision'],
#          'precision_class_2' : report_dict_gnb['2']['precision'],
#          'precision_class_3' : report_dict_gnb['3']['precision'],
#          'f1-score_macro' : report_dict_gnb['macro avg']['f1-score'],
#          'f1-score_weighted' : report_dict_gnb['weighted avg']['f1-score'],         
#         }
#     )
#     mlflow.sklearn.log_model(model_nb, "Gaussian Navive Bayes")

# %% [markdown]
# #### Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression(max_iter=1000)  # increase max_iter to avoid convergence issues
model_lr.fit(X_train, y_train)

y_pred = model_lr.predict(X_test)

accuracy_lr = accuracy_score(y_test, y_pred)
print("Accuracy on Test Data using Logistic Regression:", accuracy_lr)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on Test Data using Logistic Regression: 0.8353585258378956
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84       914
#            1       0.81      0.80      0.80      1948
#            2       0.79      0.79      0.79      2199
#            3       0.90      0.91      0.90      2428
#
#     accuracy                           0.84      7489
#    macro avg       0.83      0.83      0.83      7489
# weighted avg       0.84      0.84      0.84      7489

# %%
report_dict_lr = classification_report(y_test, y_pred, output_dict=True)
# report_dict_lr

# %%
lr_params = model_lr.get_params()
lr_params
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 1000,
#  'multi_class': 'deprecated',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# #### SVC

# %%
from sklearn.svm import SVC

# %% [markdown]
# ##### Standardize the features using StandardScaler for SVC

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model_svc = SVC(probability=True)   # kernel params are 'linear', 'poly', 'rbf', 'sigmoid'
model_svc.fit(X_train_scaled, y_train)

# --------------------------------------------------
# 6. Predict on test data
# --------------------------------------------------
y_pred = model_svc.predict(X_test_scaled)

# --------------------------------------------------
# 7. Accuracy
# --------------------------------------------------
accuracy_svc = accuracy_score(y_test, y_pred)
print("Accuracy on Test Data using SVC:", accuracy_svc)

# --------------------------------------------------
# 8. Classification Report
# --------------------------------------------------
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on Test Data using SVC: 0.8782213913740152
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.89       914
#            1       0.86      0.86      0.86      1948
#            2       0.83      0.85      0.84      2199
#            3       0.93      0.92      0.93      2428
#
#     accuracy                           0.88      7489
#    macro avg       0.88      0.88      0.88      7489
# weighted avg       0.88      0.88      0.88      7489

# %%
report_dict_svc = classification_report(y_test, y_pred, output_dict=True)
# report_dict_svc

# %%
svc_params = model_svc.get_params()
svc_params
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier(
    # n_estimators=100,     # number of trees
    # max_depth=None,       # fully grown trees
    random_state=42,
    n_jobs=-1             # use all CPU cores
)

model_rf.fit(X_train, y_train)

y_pred = model_rf.predict(X_test)

accuracy_rf = accuracy_score(y_test, y_pred)
print("Accuracy on Test Data using RandomForestClassifier:", accuracy_rf)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on Test Data using RandomForestClassifier: 0.8967819468553879
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91       914
#            1       0.88      0.88      0.88      1948
#            2       0.85      0.88      0.86      2199
#            3       0.94      0.93      0.94      2428
#
#     accuracy                           0.90      7489
#    macro avg       0.90      0.90      0.90      7489
# weighted avg       0.90      0.90      0.90      7489

# %%
report_dict_rf = classification_report(y_test, y_pred, output_dict=True)
# report_dict_rf

# %%
rf_params = model_rf.get_params()
rf_params
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# #### XGBoost

# %%
from xgboost import XGBClassifier

# %%
model_xgb = XGBClassifier(
    # n_estimators=200,
    # learning_rate=0.1,
    # max_depth=6,
    # subsample=0.8,
    # colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)

model_xgb.fit(X_train, y_train)

y_pred = model_xgb.predict(X_test)

accuracy_xgb = accuracy_score(y_test, y_pred)
print("Accuracy on Test Data using XGboost Classifier:", accuracy_xgb)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy on Test Data using XGboost Classifier: 0.927627186540259
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       914
#            1       0.93      0.91      0.92      1948
#            2       0.89      0.92      0.91      2199
#            3       0.96      0.95      0.95      2428
#
#     accuracy                           0.93      7489
#    macro avg       0.93      0.93      0.93      7489
# weighted avg       0.93      0.93      0.93      7489

# %%
report_dict_xgb = classification_report(y_test, y_pred, output_dict=True)
# report_dict_xgb

# %%
xgb_params = model_xgb.get_params()
xgb_params
# Out:
# {'objective': 'multi:softprob',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'device': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'feature_weights': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': None,
#  'n_jobs': -1,
#  'num_parallel_tree': None,
#  'random_state': 42,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %% [markdown]
# #### Light GBM

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\inspire\appdata\local\programs\python\python310\lib\site-packages (4.6.0)
# Requirement already satisfied: scipy in c:\users\inspire\appdata\local\programs\python\python310\lib\site-packages (from lightgbm) (1.15.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\inspire\appdata\local\programs\python\python310\lib\site-packages (from lightgbm) (1.26.4)
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import lightgbm as lgb

model_lgb = lgb.LGBMClassifier(
    # n_estimators=300,
    # learning_rate=0.05,
    # max_depth=-1,           # -1 means no limit
    # num_leaves=31,
    # subsample=0.8,
    # colsample_bytree=0.8,
    random_state=42
)

# %%
model_lgb.fit(X_train, y_train)

y_pred = model_lgb.predict(X_test)

accuracy_lgb = accuracy_score(y_test, y_pred)
print("Accuracy on Test Data using Light GBM:", accuracy_lgb)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000764 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 82
# [LightGBM] [Info] Number of data points in the train set: 22467, number of used features: 24
# [LightGBM] [Info] Start training from score -2.103725
# [LightGBM] [Info] Start training from score -1.346461
# [LightGBM] [Info] Start training from score -1.225281
# [LightGBM] [Info] Start training from score -1.126505
# Accuracy on Test Data using Light GBM: 0.9285618907731339
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93       914
#            1       0.92      0.91      0.92      1948
#            2       0.89      0.92      0.91      2199
#            3       0.96      0.95      0.96      2428
#
#     accuracy                           0.93      7489
#    macro avg       0.93      0.93      0.93      7489
# weighted avg       0.93      0.93      0.93      7489

# %%
report_dict_lgb = classification_report(y_test, y_pred, output_dict=True)
# report_dict_lgb

# %%
lgb_params = model_lgb.get_params()
lgb_params
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': 42,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %% [markdown]
# #### Single function to log the models using MLFlow

# %%
MODEL_NAMES = [
    "Gaussian NB",
    "Logistic Regression",
    "Random Forest",
    "SVC",
    "XGBoost",
    "LightGBM"
]

# %%
def log_model_to_mlflow(model_name, model, params, report_dict):

    model_id = MODEL_NAMES.index(model_name)

    with mlflow.start_run(run_name=model_name):

        # Human-readable tag (click run → see model name)
        mlflow.set_tag("model_name", model_name)

        # Numeric model ID (shown on charts)
        mlflow.log_param("model_name_id", model_id)

        # Log hyperparameters
        mlflow.log_params(params)

        # Log metrics
        metrics = {
            'accuracy': report_dict['accuracy'],
            'f1_macro': report_dict['macro avg']['f1-score'],
            'f1_weighted': report_dict['weighted avg']['f1-score'],
        }

        for cls in ['0', '1', '2', '3']:
            metrics[f'precision_class_{cls}'] = report_dict[cls]['precision']
            metrics[f'recall_class_{cls}'] = report_dict[cls]['recall']

        mlflow.log_metrics(metrics)

        # Save model
        mlflow.sklearn.log_model(model, artifact_path=model_name)

# %%
# Set these ONCE at the top
mlflow.set_experiment("Beverage Price Predictor")
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# --- Gaussian NB ---
log_model_to_mlflow("Gaussian NB", model_nb, nb_params, report_dict_gnb)

# --- Logistic Regression ---
log_model_to_mlflow("Logistic Regression", model_lr, lr_params, report_dict_lr)

# --- Random Forest ---
log_model_to_mlflow("Random Forest", model_rf, rf_params, report_dict_rf)

# --- SVC ---
log_model_to_mlflow("SVC", model_svc, svc_params, report_dict_svc)
# Out:
# 2025/11/26 20:40:27 INFO mlflow.tracking.fluent: Experiment with name 'Beverage Price Predictor' does not exist. Creating a new experiment.
# C:\Users\Inspire\AppData\Local\Programs\Python\Python310\lib\site-packages\_distutils_hack\__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# C:\Users\Inspire\AppData\Local\Programs\Python\Python310\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
model_name = "XGBoost"
model_name_id = MODEL_NAMES.index(model_name)

with mlflow.start_run(run_name=model_name):

    # Human-readable model name (shows in Run Table)
    mlflow.set_tag("model_name", model_name)

    # Numeric ID used in Parallel Coordinates Plot
    mlflow.log_param("model_name_id", model_name_id)

    # Log hyperparameters
    mlflow.log_params(xgb_params)

    # Log metrics
    metrics = {
        'accuracy': report_dict_xgb['accuracy'],
        'f1_macro': report_dict_xgb['macro avg']['f1-score'],
        'f1_weighted': report_dict_xgb['weighted avg']['f1-score'],
    }

    # Add per-class precision & recall automatically
    for cls in ['0', '1', '2', '3']:
        metrics[f'precision_class_{cls}'] = report_dict_xgb[cls]['precision']
        metrics[f'recall_class_{cls}'] = report_dict_xgb[cls]['recall']

    mlflow.log_metrics(metrics)

    # Log XGBoost model
    mlflow.xgboost.log_model(model_xgb, artifact_path=model_name)
# Out:
# C:\Users\Inspire\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:1028: UserWarning: [20:41:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\c_api\c_api.cc:1427: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   self.get_booster().save_model(fname)

# %%
model_name = "LightGBM"
model_name_id = MODEL_NAMES.index(model_name)

with mlflow.start_run(run_name=model_name):

    # Human-readable model name tag
    mlflow.set_tag("model_name", model_name)

    # Numeric model name ID (used in MLflow visualizations)
    mlflow.log_param("model_name_id", model_name_id)

    # Log hyperparameters
    mlflow.log_params(lgb_params)

    # Log metrics
    metrics = {
        'accuracy': report_dict_lgb['accuracy'],
        'f1_macro': report_dict_lgb['macro avg']['f1-score'],
        'f1_weighted': report_dict_lgb['weighted avg']['f1-score'],
    }

    # Add per-class precision & recall
    for cls in ['0', '1', '2', '3']:
        metrics[f'precision_class_{cls}'] = report_dict_lgb[cls]['precision']
        metrics[f'recall_class_{cls}'] = report_dict_lgb[cls]['recall']

    mlflow.log_metrics(metrics)

    # Log LightGBM model
    mlflow.lightgbm.log_model(model_lgb, artifact_path=model_name)

# %% [markdown]
# #### Register the models

# %%
model_name = "XGBoost_Classifier"
run_id = input("Enter Run ID:")
model_uri = f"runs:/{run_id}/{model_name}"

result = mlflow.register_model(
    model_uri, model_name
)
# Out:
# Enter Run ID: 8a3cd7152c5148b0839cf303e4aba888
# Successfully registered model 'XGBoost_Classifier'.
# 2025/11/26 20:45:32 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: XGBoost_Classifier, version 1
# Created version '1' of model 'XGBoost_Classifier'.

# %%
model_name = "Light_GBM_Classifier"
run_id = input("Enter Run ID:")
model_uri = f"runs:/{run_id}/{model_name}"

result = mlflow.register_model(
    model_uri, model_name
)
# Out:
# Enter Run ID: f32289d3ec8242678211bc75996dd8a7
# Successfully registered model 'Light_GBM_Classifier'.
# 2025/11/26 20:48:46 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Light_GBM_Classifier, version 1
# Created version '1' of model 'Light_GBM_Classifier'.

# %%
model_name = "Random_Forest_Classifier"
run_id = input("Enter Run ID:")
model_uri = f"runs:/{run_id}/{model_name}"

result = mlflow.register_model(
    model_uri, model_name
)
# Out:
# Enter Run ID: 6c3f7e5a124e48adb57c7fc0998aaff8
# Successfully registered model 'Random_Forest_Classifier'.
# 2025/11/26 20:49:55 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Random_Forest_Classifier, version 1
# Created version '1' of model 'Random_Forest_Classifier'.

# %%
model_name = "Support_Vector_Classifier"
run_id = input("Enter Run ID:")
model_uri = f"runs:/{run_id}/{model_name}"

result = mlflow.register_model(
    model_uri, model_name
)
# Out:
# Enter Run ID: 2d44404182ce4f30bc824a009d64accc
# Successfully registered model 'Support_Vector_Classifier'.
# 2025/11/26 20:50:36 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Support_Vector_Classifier, version 1
# Created version '1' of model 'Support_Vector_Classifier'.

# %%
model_name = "Gaussian_Naive_Bayes_Classifier"
run_id = input("Enter Run ID:")
model_uri = f"runs:/{run_id}/{model_name}"

result = mlflow.register_model(
    model_uri, model_name
)
# Out:
# Enter Run ID: d9755f7db78540b487885598a7ab5000
# Successfully registered model 'Gaussian_Naive_Bayes_Classifier'.
# 2025/11/26 20:51:22 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Gaussian_Naive_Bayes_Classifier, version 1
# Created version '1' of model 'Gaussian_Naive_Bayes_Classifier'.

# %%
model_name = "Logistic_Regression_Classifier"
run_id = input("Enter Run ID:")
model_uri = f"runs:/{run_id}/{model_name}"

result = mlflow.register_model(
    model_uri, model_name
)
# Out:
# Enter Run ID: 964cf6439c79460881f12e8a8ee91e02
# Successfully registered model 'Logistic_Regression_Classifier'.
# 2025/11/26 20:52:09 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Logistic_Regression_Classifier, version 1
# Created version '1' of model 'Logistic_Regression_Classifier'.

# %% [markdown]
# #### Load the champion model viz., LightGBM in this case

# %%
model_uri = 'runs:/f32289d3ec8242678211bc75996dd8a7/LightGBM'
loaded_model = mlflow.lightgbm.load_model(model_uri=model_uri)

y_pred = loaded_model.predict(X_test)
y_pred[:4]
# Out:
# array([0, 1, 3, 1], dtype=int64)

# %% [markdown]
# #### Transition from development env to production env

# %%
client = mlflow.MlflowClient()
client.search_registered_models()
# Out:
# [<RegisteredModel: aliases={'naivebayes': '1'}, creation_timestamp=1764170482288, description=('This model was trained to predict the beverage price as part of CB '
#   'Internship 1.'), last_updated_timestamp=1764170504060, latest_versions=[<ModelVersion: aliases=['naivebayes'], creation_timestamp=1764170482355, current_stage='None', description='', last_updated_timestamp=1764170482355, name='Gaussian_Naive_Bayes_Classifier', run_id='d9755f7db78540b487885598a7ab5000', run_link='', source='file:///D:/Arjun/CB_VI_1/Wk_3/project_resources1/mlruns/998689494779775513/d9755f7db78540b487885598a7ab5000/artifacts/Gaussian_Naive_Bayes_Classifier', status='READY', status_message='', tags={}, user_id='', version='1'>], name='Gaussian_Naive_Bayes_Classifier', tags={}>,
#  <RegisteredModel: aliases={'champion': '1', 'lightgbm': '1'}, creation_timestamp=1764170326522, description=('This model was trained to predict the beverage price as part of CB '
#   'Internship 1.'), last_updated_timestamp=1764170671201, latest_versions=[<ModelVersion: aliases=['champion', 'lightgbm'], creation_timestamp=1764170326597, current_stage='None', description='', last_updated_timestamp=1764170326597, name='Light_GBM_Classifier', run_id='f32289d3ec8242678211bc75996dd8a7', run_link='', source='file:///D:/Arjun/CB_VI_1/Wk_3/project_resources1/mlruns/998689494779775513/f32289d3ec8242678211bc75996dd8a7/artifacts/Light_GBM_Classifier', status='READY', status_message='', tags={}, user_id='', version='1'>], name='Light_GBM_Classifier', tags={}>,
#  <RegisteredModel: aliases={'logisticregression': '1'}, creation_timestamp=1764170529159, description=('This model was trained to predict the beverage price as part of CB '
#   'Internship 1.'), last_updated_timestamp=1764170545869, latest_versions=[<ModelVersion: aliases=['logisticregression'], creation_timestamp=1764170529246, current_stage='None', description='', last_updated_timestamp=1764170529246, name='Logistic_Regression_Classifier', run_id='964cf6439c79460881f12e8a8ee91e02', run_link='', source='file:///D:/Arjun/CB_VI_1/Wk_3/project_resources1/mlruns/998689494779775513/964cf6439c79460881f12e8a8ee91e02/artifacts/Logistic_Regression_Classifier', status='READY', status_message='', tags={}, user_id='', version='1'>], name='Logistic_Regression_Classifier', tags={}>,
#  <RegisteredModel: aliases={'randomforest': '1'}, creation_timestamp=1764170395389, description=('This model was trained to predict the beverage price as part of CB '
#   'Internship 1.'), last_updated_timestamp=1764170411258, latest_versions=[<ModelVersion: aliases=['randomforest'], creation_timestamp=1764170395529, current_stage='None', description='', last_updated_timestamp=1764170395529, name='Random_Forest_Classifier', run_id='6c3f7e5a124e48adb57c7fc0998aaff8', run_link='', source='file:///D:/Arjun/CB_VI_1/Wk_3/project_resources1/mlruns/998689494779775513/6c3f7e5a124e48adb57c7fc0998aaff8/artifacts/Random_Forest_Classifier', status='READY', status_message='', tags={}, user_id='', version='1'>], name='Random_Forest_Classifier', tags={}>,
#  <RegisteredModel: aliases={'svc': '1'}, creation_timestamp=1764170436377, description=('This model was trained to predict the beverage price as part of CB '
#   'Internship 1.'), last_updated_timestamp=1764170450218, latest_versions=[<ModelVersion: aliases=['svc'], creation_timestamp=1764170436462, current_stage='None', description='', last_updated_timestamp=1764170436462, name='Support_Vector_Classifier', run_id='2d44404182ce4f30bc824a009d64accc', run_link='', source='file:///D:/Arjun/CB_VI_1/Wk_3/project_resources1/mlruns/998689494779775513/2d44404182ce4f30bc824a009d64accc/artifacts/Support_Vector_Classifier', status='READY', status_message='', tags={}, user_id='', version='1'>], name='Support_Vector_Classifier', tags={}>,
#  <RegisteredModel: aliases={'xgboost': '1'}, creation_timestamp=1764170131962, description=('This model was trained to predict the beverage price as part of CB '
#   'Internship 1.'), last_updated_timestamp=1764170263108, latest_versions=[<ModelVersion: aliases=['xgboost'], creation_timestamp=1764170132056, current_stage='None', description=('This model was trained to predict the beverage price as part of CB '
#   'Internship 1.'), last_updated_timestamp=1764170221703, name='XGBoost_Classifier', run_id='8a3cd7152c5148b0839cf303e4aba888', run_link='', source='file:///D:/Arjun/CB_VI_1/Wk_3/project_resources1/mlruns/998689494779775513/8a3cd7152c5148b0839cf303e4aba888/artifacts/XGBoost_Classifier', status='READY', status_message='', tags={}, user_id='', version='1'>], name='XGBoost_Classifier', tags={}>]

# %%
development_model_uri = "models:/Light_GBM_Classifier@champion"
production_model_uri = 'beverage_price_predictor'

client.copy_model_version(src_model_uri=development_model_uri,dst_name=production_model_uri)
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1764171538848, current_stage='None', description='', last_updated_timestamp=1764171538848, name='beverage_price_predictor', run_id='f32289d3ec8242678211bc75996dd8a7', run_link='', source='models:/Light_GBM_Classifier/1', status='READY', status_message='', tags={}, user_id='', version='1'>

# %% [markdown]
# #### Load production model & make prediction

# %%
# Load the production model from the MLflow Model Registry
model_uri = "runs:/f32289d3ec8242678211bc75996dd8a7/LightGBM"
loaded_model = mlflow.lightgbm.load_model(model_uri)

# Make predictions locally
y_pred = loaded_model.predict(X_test)
y_pred[:4]
# Out:
# array([0, 1, 3, 1], dtype=int64)
